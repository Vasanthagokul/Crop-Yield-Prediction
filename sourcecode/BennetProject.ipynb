# %% [markdown]
# #Drive Mounting

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #**CROP YIELD PREDICTION**

# %% [markdown]
# #Dataset 1

# %% [markdown]
# ##Reading Dataset

# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Bennet/apy.csv', encoding='utf-8')
df
# Out:
#                          State_Name District_Name  ...  Production     Yield
# 0       Andaman and Nicobar Islands      NICOBARS  ...      2000.0  1.594896
# 1       Andaman and Nicobar Islands      NICOBARS  ...         1.0  0.500000
# 2       Andaman and Nicobar Islands      NICOBARS  ...       321.0  3.147059
# 3       Andaman and Nicobar Islands      NICOBARS  ...       641.0  3.642045
# 4       Andaman and Nicobar Islands      NICOBARS  ...       165.0  0.229167
# ...                             ...           ...  ...         ...       ...
# 246086                  West Bengal       PURULIA  ...       801.0       NaN
# 246087                  West Bengal       PURULIA  ...       463.0       NaN
# 246088                  West Bengal       PURULIA  ...     16250.0       NaN
# 246089                  West Bengal       PURULIA  ...    597899.0       NaN
# 246090                  West Bengal       PURULIA  ...        88.0       NaN
#
# [246091 rows x 8 columns]

# %% [markdown]
# ##Reducing Data to One State for Ease

# %%
df = df[df['State_Name'] == "Andhra Pradesh"]

# %% [markdown]
# ###Making Yield Column

# %%
df['Yield'] = df['Production']/df['Area']
df
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           State_Name  District_Name  ...   Production         Yield
# 203   Andhra Pradesh      ANANTAPUR  ...       2600.0      0.121495
# 204   Andhra Pradesh      ANANTAPUR  ...        500.0      0.357143
# 205   Andhra Pradesh      ANANTAPUR  ...        100.0      0.100000
# 206   Andhra Pradesh      ANANTAPUR  ...       9400.0      1.287671
# 207   Andhra Pradesh      ANANTAPUR  ...       7100.0      1.918919
# ...              ...            ...  ...          ...           ...
# 9826  Andhra Pradesh  WEST GODAVARI  ...      89107.0      3.177173
# 9827  Andhra Pradesh  WEST GODAVARI  ...       3035.0     13.549107
# 9828  Andhra Pradesh  WEST GODAVARI  ...       4833.0      0.892027
# 9829  Andhra Pradesh  WEST GODAVARI  ...  718991000.0  33089.005477
# 9830  Andhra Pradesh  WEST GODAVARI  ...    1624324.0      3.968677
#
# [9628 rows x 8 columns]

# %% [markdown]
# ##Corelation Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sb

C_mat = df.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %% [markdown]
# ##Taking Data only after 2004

# %%
df = df[df['Crop_Year']>=2004]
df
# Out:
#           State_Name  District_Name  ...   Production         Yield
# 493   Andhra Pradesh      ANANTAPUR  ...       7893.0      0.240993
# 494   Andhra Pradesh      ANANTAPUR  ...        403.0      0.394711
# 495   Andhra Pradesh      ANANTAPUR  ...        923.0      0.584918
# 496   Andhra Pradesh      ANANTAPUR  ...       7041.0      0.788201
# 497   Andhra Pradesh      ANANTAPUR  ...      11288.0      3.318048
# ...              ...            ...  ...          ...           ...
# 9826  Andhra Pradesh  WEST GODAVARI  ...      89107.0      3.177173
# 9827  Andhra Pradesh  WEST GODAVARI  ...       3035.0     13.549107
# 9828  Andhra Pradesh  WEST GODAVARI  ...       4833.0      0.892027
# 9829  Andhra Pradesh  WEST GODAVARI  ...  718991000.0  33089.005477
# 9830  Andhra Pradesh  WEST GODAVARI  ...    1624324.0      3.968677
#
# [5999 rows x 8 columns]

# %% [markdown]
# ##Encoding All Categorical Data

# %%
df = df.join(pd.get_dummies(df['District_Name']))
df = df.join(pd.get_dummies(df['Season']))
df = df.join(pd.get_dummies(df['Crop']))
df = df.join(pd.get_dummies(df['Crop_Year']))
df = df.join(pd.get_dummies(df['State_Name']))
df
# Out:
#           State_Name  District_Name  Crop_Year  ... 2013 2014  Andhra Pradesh
# 493   Andhra Pradesh      ANANTAPUR       2004  ...    0    0               1
# 494   Andhra Pradesh      ANANTAPUR       2004  ...    0    0               1
# 495   Andhra Pradesh      ANANTAPUR       2004  ...    0    0               1
# 496   Andhra Pradesh      ANANTAPUR       2004  ...    0    0               1
# 497   Andhra Pradesh      ANANTAPUR       2004  ...    0    0               1
# ...              ...            ...        ...  ...  ...  ...             ...
# 9826  Andhra Pradesh  WEST GODAVARI       2014  ...    0    1               1
# 9827  Andhra Pradesh  WEST GODAVARI       2014  ...    0    1               1
# 9828  Andhra Pradesh  WEST GODAVARI       2014  ...    0    1               1
# 9829  Andhra Pradesh  WEST GODAVARI       2014  ...    0    1               1
# 9830  Andhra Pradesh  WEST GODAVARI       2014  ...    0    1               1
#
# [5999 rows x 89 columns]

# %% [markdown]
# ##Dropping Unecessory Columns

# %%
df=df.drop('District_Name', axis=1)
df = df.drop('Season',axis=1)
df = df.drop('Crop',axis=1)
df = df.drop('Crop_Year', axis=1)
df = df.drop('Production', axis=1)
df = df.drop('State_Name', axis=1)
df
# Out:
#           Area         Yield  ANANTAPUR  ...  2013  2014  Andhra Pradesh
# 493    32752.0      0.240993          1  ...     0     0               1
# 494     1021.0      0.394711          1  ...     0     0               1
# 495     1578.0      0.584918          1  ...     0     0               1
# 496     8933.0      0.788201          1  ...     0     0               1
# 497     3402.0      3.318048          1  ...     0     0               1
# ...        ...           ...        ...  ...   ...   ...             ...
# 9826   28046.0      3.177173          0  ...     0     1               1
# 9827     224.0     13.549107          0  ...     0     1               1
# 9828    5418.0      0.892027          0  ...     0     1               1
# 9829   21729.0  33089.005477          0  ...     0     1               1
# 9830  409286.0      3.968677          0  ...     0     1               1
#
# [5999 rows x 83 columns]

# %% [markdown]
# ##Preprocessing

# %%
from sklearn import preprocessing

# %%
# Create x, where x the 'scores' column's values as floats
x = df[['Area']].values.astype(float)
x
# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()

# Create an object to transform the data to fit minmax processor
x_scaled = min_max_scaler.fit_transform(x)

# Run the normalizer on the dataframe
#df_normalized = pd.DataFrame(x_scaled)
x_scaled

df['Area'] = x_scaled
df
# Out:
#           Area         Yield  ANANTAPUR  ...  2013  2014  Andhra Pradesh
# 493   0.037343      0.240993          1  ...     0     0               1
# 494   0.001163      0.394711          1  ...     0     0               1
# 495   0.001798      0.584918          1  ...     0     0               1
# 496   0.010184      0.788201          1  ...     0     0               1
# 497   0.003878      3.318048          1  ...     0     0               1
# ...        ...           ...        ...  ...   ...   ...             ...
# 9826  0.031977      3.177173          0  ...     0     1               1
# 9827  0.000254     13.549107          0  ...     0     1               1
# 9828  0.006177      0.892027          0  ...     0     1               1
# 9829  0.024775  33089.005477          0  ...     0     1               1
# 9830  0.466673      3.968677          0  ...     0     1               1
#
# [5999 rows x 83 columns]

# %%
df.head()
# Out:
#          Area     Yield  ANANTAPUR  CHITTOOR  ...  2012  2013  2014  Andhra Pradesh
# 493  0.037343  0.240993          1         0  ...     0     0     0               1
# 494  0.001163  0.394711          1         0  ...     0     0     0               1
# 495  0.001798  0.584918          1         0  ...     0     0     0               1
# 496  0.010184  0.788201          1         0  ...     0     0     0               1
# 497  0.003878  3.318048          1         0  ...     0     0     0               1
#
# [5 rows x 83 columns]

# %% [markdown]
# ### Filling Empty Values With Mean

# %%
df = df.fillna(df.mean())

# %% [markdown]
# ##Train and Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
b = df['Yield']
a = df.drop('Yield', axis = 1)

a_train, a_test, b_train, b_test = train_test_split(a, b, test_size = 0.3, random_state = 42)

print(a_train)
print(a_test)
print(b_train)
print(b_test)
# Out:
#           Area  ANANTAPUR  CHITTOOR  ...  2013  2014  Andhra Pradesh
# 1711  0.000246          0         1  ...     1     0               1
# 5452  0.031408          0         0  ...     1     0               1
# 538   0.003756          1         0  ...     0     0               1
# 2336  0.014880          0         0  ...     0     0               1
# 2172  0.001397          0         0  ...     0     0               1
# ...        ...        ...       ...  ...   ...   ...             ...
# 6278  0.001999          0         0  ...     0     1               1
# 8796  0.000129          0         0  ...     0     0               1
# 8831  0.000385          0         0  ...     0     0               1
# 8995  0.000344          0         0  ...     0     0               1
# 1644  0.000268          0         1  ...     0     0               1
#
# [4199 rows x 82 columns]
#           Area  ANANTAPUR  CHITTOOR  ...  2013  2014  Andhra Pradesh
# 577   0.000706          1         0  ...     0     0               1
# 4044  0.000341          0         0  ...     0     1               1
# 8328  0.000667          0         0  ...     0     0               1
# 839   0.002276          1         0  ...     0     0               1
# 572   0.055501          1         0  ...     0     0               1
# ...        ...        ...       ...  ...   ...   ...             ...
# 1625  0.000011          0         1  ...     0     0               1
# 4457  0.000047          0         0  ...     0     0               1
# 2265  0.000426          0         0  ...     0     0               1
# 668   0.048193          1         0  ...     0     0               1
# 3867  0.000472          0         0  ...     0     0               1
#
# [1800 rows x 82 columns]
# 1711    11.741935
# 5452     0.469997
# 538      1.047041
# 2336    83.248104
# 2172     0.256117
#           ...
# 6278     6.176169
# 8796    16.964912
# 8831     0.554572
# 8995    25.392739
# 1644     0.673729
# Name: Yield, Length: 4199, dtype: float64
# 577     0.304839
# 4044    0.310000
# 8328    2.470990
# 839     0.661993
# 572     0.172587
#           ...
# 1625    1.818182
# 4457    1.023810
# 2265    0.765333
# 668     0.622338
# 3867    0.481928
# Name: Yield, Length: 1800, dtype: float64

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
a_train = sc.fit_transform(a_train)
a_test = sc.transform(a_test)

# %%
score_p = []

# %% [markdown]
# ###Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=2, random_state=0, n_estimators=100)
regr.fit(a_train, b_train)
b_pred = regr.predict(a_test)

from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import r2_score

print('MSE =', mse(b_test, b_pred))
print('MAE =', mae(b_test, b_pred))
print('R2 Score =', r2_score(b_test,b_pred))
# Out:
# MSE = 344244.0619993072
# MAE = 79.0739528510798
# R2 Score = 0.8863535872418126

# %%
score_p.append([mse(b_test, b_pred), mae(b_test, b_pred)])

# %% [markdown]
# ###Polynomial Support Vector Machine

# %%
from sklearn.svm import SVR
regressorpoly=SVR(kernel='poly',epsilon=1.0)
regressorpoly.fit(a_train,b_train)
pred=regressorpoly.predict(a_test)

print('MSE =', mse(b_test, pred))
print('MAE =', mae(b_test, pred))
print('R2 Score =', r2_score(b_test,pred))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# MSE = 3072509.905638075
# MAE = 240.95872644791754
# R2 Score = -0.014337696667276134

# %%
score_p.append([mse(b_test, pred), mae(b_test, pred)])

# %% [markdown]
# ###XGBRegressor

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
XGBModel = XGBRegressor()
XGBModel.fit(a_train,b_train , verbose=False)

# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(a_test)
MSE = mean_squared_error(b_test , XGBpredictions)
MAE = mean_absolute_error(b_test , XGBpredictions)
print('XGBoost validation MAE = ',MAE)
print('XGBoost validation MSE = ',MSE)
print('R2 Score =', r2_score(b_test,XGBpredictions))
# Out:
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [17:30:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBoost validation MAE =  49.870773418945774
# XGBoost validation MSE =  165788.24235463896
# R2 Score = 0.9452677878837962

# %%
score_p.append([MSE, MAE])

# %% [markdown]
# ##Neural Network Implementation

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
from keras.callbacks import History 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = a_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'accuracy'])
NN_model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4409: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               10624
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 175,489
# Trainable params: 175,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import History 
history = History()
History=NN_model.fit(a_train, b_train, epochs=50, batch_size=500, validation_data=(a_test, b_test), callbacks=[history])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 4199 samples, validate on 1800 samples
# Epoch 1/50
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 4199/4199 [==============================] - 9s 2ms/step - loss: 3120408.7143 - mean_absolute_error: 230.7269 - acc: 0.0050 - val_loss: 3086893.3333 - val_mean_absolute_error: 244.6746 - val_acc: 0.0017
# Epoch 2/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 3113270.3216 - mean_absolute_error: 233.8010 - acc: 7.1446e-04 - val_loss: 3065003.8819 - val_mean_absolute_error: 259.8419 - val_acc: 0.0000e+00
# Epoch 3/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 3064696.9423 - mean_absolute_error: 267.1663 - acc: 0.0000e+00 - val_loss: 2941210.1597 - val_mean_absolute_error: 333.0464 - val_acc: 0.0000e+00
# Epoch 4/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 2868818.3487 - mean_absolute_error: 392.0224 - acc: 0.0000e+00 - val_loss: 2537726.0000 - val_mean_absolute_error: 539.7697 - val_acc: 0.0000e+00
# Epoch 5/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 2385934.2751 - mean_absolute_error: 628.6040 - acc: 0.0000e+00 - val_loss: 1906608.0625 - val_mean_absolute_error: 733.1280 - val_acc: 0.0000e+00
# Epoch 6/50
# 4199/4199 [==============================] - 0s 16us/step - loss: 1661526.3709 - mean_absolute_error: 743.8883 - acc: 0.0000e+00 - val_loss: 1083071.0833 - val_mean_absolute_error: 655.2930 - val_acc: 0.0000e+00
# Epoch 7/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 871933.5330 - mean_absolute_error: 500.2981 - acc: 2.3815e-04 - val_loss: 460794.1953 - val_mean_absolute_error: 241.5634 - val_acc: 5.5556e-04
# Epoch 8/50
# 4199/4199 [==============================] - 0s 14us/step - loss: 464786.5468 - mean_absolute_error: 168.0772 - acc: 7.1446e-04 - val_loss: 399339.7882 - val_mean_absolute_error: 104.4744 - val_acc: 5.5556e-04
# Epoch 9/50
# 4199/4199 [==============================] - 0s 16us/step - loss: 386804.4946 - mean_absolute_error: 83.5561 - acc: 0.0048 - val_loss: 324630.1354 - val_mean_absolute_error: 77.5114 - val_acc: 0.0033
# Epoch 10/50
# 4199/4199 [==============================] - 0s 17us/step - loss: 361305.7882 - mean_absolute_error: 73.0626 - acc: 0.0048 - val_loss: 303895.7821 - val_mean_absolute_error: 81.5374 - val_acc: 5.5556e-04
# Epoch 11/50
# 4199/4199 [==============================] - 0s 17us/step - loss: 323947.5667 - mean_absolute_error: 80.0152 - acc: 0.0000e+00 - val_loss: 271127.4931 - val_mean_absolute_error: 81.8523 - val_acc: 0.0011
# Epoch 12/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 292886.6115 - mean_absolute_error: 76.3169 - acc: 2.3815e-04 - val_loss: 246722.9453 - val_mean_absolute_error: 80.3132 - val_acc: 5.5556e-04
# Epoch 13/50
# 4199/4199 [==============================] - 0s 14us/step - loss: 263164.0625 - mean_absolute_error: 73.7512 - acc: 7.1446e-04 - val_loss: 232274.3963 - val_mean_absolute_error: 75.7558 - val_acc: 0.0011
# Epoch 14/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 257989.2884 - mean_absolute_error: 65.4628 - acc: 0.0012 - val_loss: 195450.4466 - val_mean_absolute_error: 66.8739 - val_acc: 5.5556e-04
# Epoch 15/50
# 4199/4199 [==============================] - 0s 14us/step - loss: 212677.9558 - mean_absolute_error: 61.7921 - acc: 9.5261e-04 - val_loss: 186955.2682 - val_mean_absolute_error: 68.7828 - val_acc: 0.0017
# Epoch 16/50
# 4199/4199 [==============================] - 0s 12us/step - loss: 197855.4264 - mean_absolute_error: 59.4843 - acc: 0.0019 - val_loss: 155353.6202 - val_mean_absolute_error: 59.1141 - val_acc: 5.5556e-04
# Epoch 17/50
# 4199/4199 [==============================] - 0s 14us/step - loss: 175164.3713 - mean_absolute_error: 55.5997 - acc: 0.0014 - val_loss: 164396.0586 - val_mean_absolute_error: 64.4607 - val_acc: 0.0022
# Epoch 18/50
# 4199/4199 [==============================] - 0s 13us/step - loss: 163825.2052 - mean_absolute_error: 53.4839 - acc: 0.0017 - val_loss: 124316.4974 - val_mean_absolute_error: 49.3845 - val_acc: 0.0000e+00
# Epoch 19/50
# 4199/4199 [==============================] - 0s 12us/step - loss: 157545.4013 - mean_absolute_error: 47.9689 - acc: 0.0012 - val_loss: 122769.1584 - val_mean_absolute_error: 50.3110 - val_acc: 0.0028
# Epoch 20/50
# 4199/4199 [==============================] - 0s 13us/step - loss: 143476.3647 - mean_absolute_error: 48.5117 - acc: 7.1446e-04 - val_loss: 129733.0438 - val_mean_absolute_error: 51.9105 - val_acc: 0.0017
# Epoch 21/50
# 4199/4199 [==============================] - 0s 13us/step - loss: 137615.2160 - mean_absolute_error: 45.8442 - acc: 9.5261e-04 - val_loss: 112961.3898 - val_mean_absolute_error: 43.9996 - val_acc: 0.0011
# Epoch 22/50
# 4199/4199 [==============================] - 0s 13us/step - loss: 143397.5925 - mean_absolute_error: 46.8351 - acc: 4.7630e-04 - val_loss: 118626.6092 - val_mean_absolute_error: 46.4427 - val_acc: 0.0011
# Epoch 23/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 134615.9314 - mean_absolute_error: 44.7805 - acc: 0.0017 - val_loss: 107960.5393 - val_mean_absolute_error: 43.6811 - val_acc: 0.0011
# Epoch 24/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 130529.3053 - mean_absolute_error: 44.4705 - acc: 0.0012 - val_loss: 113524.7609 - val_mean_absolute_error: 44.7449 - val_acc: 5.5556e-04
# Epoch 25/50
# 4199/4199 [==============================] - 0s 13us/step - loss: 126230.9734 - mean_absolute_error: 43.1388 - acc: 0.0017 - val_loss: 109992.0718 - val_mean_absolute_error: 43.3092 - val_acc: 0.0022
# Epoch 26/50
# 4199/4199 [==============================] - 0s 13us/step - loss: 119974.0406 - mean_absolute_error: 41.1055 - acc: 0.0021 - val_loss: 104166.3448 - val_mean_absolute_error: 41.5884 - val_acc: 0.0022
# Epoch 27/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 118218.2275 - mean_absolute_error: 40.3360 - acc: 0.0021 - val_loss: 105434.5412 - val_mean_absolute_error: 41.6829 - val_acc: 5.5556e-04
# Epoch 28/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 114114.4657 - mean_absolute_error: 39.2768 - acc: 0.0019 - val_loss: 113287.0332 - val_mean_absolute_error: 43.9236 - val_acc: 0.0011
# Epoch 29/50
# 4199/4199 [==============================] - 0s 14us/step - loss: 117951.5425 - mean_absolute_error: 39.7368 - acc: 0.0017 - val_loss: 103407.6901 - val_mean_absolute_error: 40.2183 - val_acc: 0.0033
# Epoch 30/50
# 4199/4199 [==============================] - 0s 16us/step - loss: 114324.5462 - mean_absolute_error: 38.3822 - acc: 0.0026 - val_loss: 112712.1139 - val_mean_absolute_error: 42.2573 - val_acc: 0.0039
# Epoch 31/50
# 4199/4199 [==============================] - 0s 18us/step - loss: 128508.5774 - mean_absolute_error: 42.5463 - acc: 0.0024 - val_loss: 103238.2678 - val_mean_absolute_error: 41.7369 - val_acc: 0.0039
# Epoch 32/50
# 4199/4199 [==============================] - 0s 13us/step - loss: 133987.5807 - mean_absolute_error: 41.3729 - acc: 0.0021 - val_loss: 119279.0404 - val_mean_absolute_error: 42.5158 - val_acc: 0.0033
# Epoch 33/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 111894.2873 - mean_absolute_error: 36.7802 - acc: 0.0033 - val_loss: 103536.0089 - val_mean_absolute_error: 38.7511 - val_acc: 0.0028
# Epoch 34/50
# 4199/4199 [==============================] - 0s 16us/step - loss: 107529.2357 - mean_absolute_error: 36.4551 - acc: 0.0021 - val_loss: 100169.5362 - val_mean_absolute_error: 38.3730 - val_acc: 0.0039
# Epoch 35/50
# 4199/4199 [==============================] - 0s 19us/step - loss: 102566.0463 - mean_absolute_error: 36.0892 - acc: 0.0033 - val_loss: 97484.5833 - val_mean_absolute_error: 38.5485 - val_acc: 0.0050
# Epoch 36/50
# 4199/4199 [==============================] - 0s 16us/step - loss: 112558.6604 - mean_absolute_error: 37.5162 - acc: 0.0029 - val_loss: 112097.7589 - val_mean_absolute_error: 40.1404 - val_acc: 0.0022
# Epoch 37/50
# 4199/4199 [==============================] - 0s 16us/step - loss: 98693.7919 - mean_absolute_error: 35.5628 - acc: 0.0019 - val_loss: 101070.3724 - val_mean_absolute_error: 39.2867 - val_acc: 0.0050
# Epoch 38/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 104694.0253 - mean_absolute_error: 35.8413 - acc: 0.0021 - val_loss: 101424.8531 - val_mean_absolute_error: 38.3609 - val_acc: 0.0050
# Epoch 39/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 95480.1556 - mean_absolute_error: 35.0084 - acc: 0.0033 - val_loss: 98875.9518 - val_mean_absolute_error: 38.2277 - val_acc: 0.0044
# Epoch 40/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 93808.5275 - mean_absolute_error: 33.8334 - acc: 0.0033 - val_loss: 103772.2086 - val_mean_absolute_error: 38.8652 - val_acc: 0.0044
# Epoch 41/50
# 4199/4199 [==============================] - 0s 17us/step - loss: 98442.0963 - mean_absolute_error: 35.8796 - acc: 0.0040 - val_loss: 94486.0592 - val_mean_absolute_error: 39.0303 - val_acc: 0.0050
# Epoch 42/50
# 4199/4199 [==============================] - 0s 16us/step - loss: 93194.8205 - mean_absolute_error: 36.3194 - acc: 0.0026 - val_loss: 111134.4245 - val_mean_absolute_error: 38.3517 - val_acc: 0.0039
# Epoch 43/50
# 4199/4199 [==============================] - 0s 13us/step - loss: 92996.8321 - mean_absolute_error: 33.0527 - acc: 0.0055 - val_loss: 95740.6513 - val_mean_absolute_error: 38.4544 - val_acc: 0.0044
# Epoch 44/50
# 4199/4199 [==============================] - 0s 13us/step - loss: 81681.4468 - mean_absolute_error: 32.0113 - acc: 0.0048 - val_loss: 103803.0441 - val_mean_absolute_error: 37.3214 - val_acc: 0.0050
# Epoch 45/50
# 4199/4199 [==============================] - 0s 14us/step - loss: 81557.0734 - mean_absolute_error: 32.1042 - acc: 0.0036 - val_loss: 92340.2038 - val_mean_absolute_error: 36.9199 - val_acc: 0.0039
# Epoch 46/50
# 4199/4199 [==============================] - 0s 15us/step - loss: 77602.4387 - mean_absolute_error: 30.4190 - acc: 0.0036 - val_loss: 97751.0082 - val_mean_absolute_error: 36.9963 - val_acc: 0.0039
# Epoch 47/50
# 4199/4199 [==============================] - 0s 17us/step - loss: 78224.9556 - mean_absolute_error: 31.4882 - acc: 0.0050 - val_loss: 95033.6687 - val_mean_absolute_error: 36.3669 - val_acc: 0.0050
# Epoch 48/50
# 4199/4199 [==============================] - 0s 19us/step - loss: 76222.9901 - mean_absolute_error: 30.4751 - acc: 0.0045 - val_loss: 95318.9715 - val_mean_absolute_error: 36.0435 - val_acc: 0.0033
# Epoch 49/50
# 4199/4199 [==============================] - 0s 17us/step - loss: 67573.7748 - mean_absolute_error: 28.5127 - acc: 0.0038 - val_loss: 81295.7559 - val_mean_absolute_error: 36.3687 - val_acc: 0.0033
# Epoch 50/50
# 4199/4199 [==============================] - 0s 19us/step - loss: 66967.7492 - mean_absolute_error: 28.5343 - acc: 0.0031 - val_loss: 85262.3684 - val_mean_absolute_error: 35.8907 - val_acc: 0.0044

# %%
plt.plot(History.history['mean_absolute_error'])
plt.plot(History.history['val_mean_absolute_error'])
plt.title('mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
 # summarize history for loss
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('model loss')
plt.ylabel('mean_squared_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
score_p.append([85262.3684, 35.8907])

# %%
score_p
# Out:
# [[344244.0619993072, 79.0739528510798],
#  [3072509.905638075, 240.95872644791754],
#  [165788.24235463896, 49.870773418945774],
#  [85262.3684, 35.8907]]

# %% [markdown]
# ## Performance Metrics of Various Methods

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

objects = ['MSE', 'MAE']
w =  0.15
y_pos = np.arange(len(objects))

color = ['#A00000','#00A0A0','#00A000', '#FFFF00']
s = 0
for i in range(len(score_p)):
    plt.bar(y_pos+s, score_p[i], color = color[i], width = w )
    s += w
    
plt.xticks(y_pos + 0.22, objects)
plt.ylabel('Scores')
plt.title('Performance')
plt.suptitle("Performance Metrics for Models", fontsize = 16, y = 1.10)

p = ['RANDOM FOREST',  'SVM', 'XGB Regression', 'Neural Network']

patches = []

for k in range(len(p)):
    patches.append(mpatches.Patch(color = color[k], label = p[k]))

plt.legend(handles = patches, bbox_to_anchor = (0.5, 1.19),loc = 'upper center', borderaxespad = 0., ncol = 4, fontsize = 'x-large')

plt.show();

# %% [markdown]
# # Dataset 2

# %% [markdown]
# ##Reading Dataset

# %%
import pandas as pd
df2 = pd.read_csv('/content/drive/My Drive/Bennet/wheat-2014-supervised.csv', encoding='utf-8')
df2
# Out:
#        CountyName       State   Latitude  ...        NDVI DayInSeason  Yield
# 0           Adams  Washington  46.929839  ...  136.179718           0   35.6
# 1           Adams  Washington  47.150327  ...  135.697540           0   35.6
# 2           Adams  Washington  46.811686  ...  135.676956           0   35.6
# 3           Adams  Washington  47.162342  ...  135.005798           0   35.6
# 4           Adams  Washington  47.157512  ...  134.803864           0   35.6
# ...           ...         ...        ...  ...         ...         ...    ...
# 182544      Miami      Kansas  38.693595  ...  134.803101         185   50.1
# 182545      Miami      Kansas  38.603699  ...  133.913879         185   50.1
# 182546      Miami      Kansas  38.580826  ...  129.938950         185   50.1
# 182547      Miami      Kansas  38.564866  ...  129.938950         185   50.1
# 182548      Miami      Kansas  38.392008  ...  129.784332         185   50.1
#
# [182549 rows x 26 columns]

# %%
df2.dtypes
# Out:
# CountyName                 object
# State                      object
# Latitude                  float64
# Longitude                 float64
# Date                       object
# apparentTemperatureMax    float64
# apparentTemperatureMin    float64
# cloudCover                float64
# dewPoint                  float64
# humidity                  float64
# precipIntensity           float64
# precipIntensityMax        float64
# precipProbability         float64
# precipAccumulation        float64
# precipTypeIsRain            int64
# precipTypeIsSnow            int64
# precipTypeIsOther           int64
# pressure                  float64
# temperatureMax            float64
# temperatureMin            float64
# visibility                float64
# windBearing                 int64
# windSpeed                 float64
# NDVI                      float64
# DayInSeason                 int64
# Yield                     float64
# dtype: object

# %% [markdown]
# ##Correlation matrix for all features

# %%
import matplotlib.pyplot as plt
import seaborn as sb


C_mat = df2.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %% [markdown]
# ##Dropping Unecessary Features

# %%
df2 = df2.drop('CountyName', axis=1)
df2 = df2.drop('State', axis=1)
df2 = df2.drop('Date', axis=1)
df2 = df2.drop('precipTypeIsOther', axis=1)
df2
# Out:
#          Latitude   Longitude  ...  DayInSeason  Yield
# 0       46.929839 -118.352109  ...            0   35.6
# 1       47.150327 -118.958859  ...            0   35.6
# 2       46.811686 -118.695237  ...            0   35.6
# 3       47.162342 -118.699677  ...            0   35.6
# 4       47.157512 -118.434056  ...            0   35.6
# ...           ...         ...  ...          ...    ...
# 182544  38.693595  -94.671846  ...          185   50.1
# 182545  38.603699  -94.992247  ...          185   50.1
# 182546  38.580826  -94.794660  ...          185   50.1
# 182547  38.564866  -94.748021  ...          185   50.1
# 182548  38.392008  -94.855430  ...          185   50.1
#
# [182549 rows x 22 columns]

# %% [markdown]
# ##Updated Corelation Matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sb

C_mat = df2.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %% [markdown]
# ##Filling missing values with mean

# %%
df2 = df2.fillna(df2.mean())
df2
# Out:
#          Latitude   Longitude  ...  DayInSeason  Yield
# 0       46.929839 -118.352109  ...            0   35.6
# 1       47.150327 -118.958859  ...            0   35.6
# 2       46.811686 -118.695237  ...            0   35.6
# 3       47.162342 -118.699677  ...            0   35.6
# 4       47.157512 -118.434056  ...            0   35.6
# ...           ...         ...  ...          ...    ...
# 182544  38.693595  -94.671846  ...          185   50.1
# 182545  38.603699  -94.992247  ...          185   50.1
# 182546  38.580826  -94.794660  ...          185   50.1
# 182547  38.564866  -94.748021  ...          185   50.1
# 182548  38.392008  -94.855430  ...          185   50.1
#
# [182549 rows x 22 columns]

# %% [markdown]
# ##Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
b1 = df2['Yield']
a1 = df2.drop('Yield', axis = 1)

a1_train, a1_test, b1_train, b1_test = train_test_split(a1, b1, test_size = 0.3, random_state = 42)

# %%
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
a1_train = sc.fit_transform(a1_train)
a1_test = sc.transform(a1_test)

# %%
score_p=[]

# %% [markdown]
# ##Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=2, random_state=0, n_estimators=100)
regr.fit(a1_train, b1_train)
b1_pred = regr.predict(a1_test)
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import r2_score

print('MSE =', mse(b1_test, b1_pred))
print('MAE =', mae(b1_test, b1_pred))
print('R2 Score =', r2_score(b1_test, b1_pred))
# Out:
# MSE = 64.98646830324311
# MAE = 6.16041791367379
# R2 Score = 0.423580379917167

# %%
score_p.append([mse(b1_test, b1_pred),mae(b1_test, b1_pred)])

# %% [markdown]
# ##Polynomial Support Vector Machine

# %%
from sklearn.svm import SVR
regressorpoly=SVR(kernel='poly',epsilon=3.0)
regressorpoly.fit(a1_train,b1_train)
pred=regressorpoly.predict(a1_test)

print('MSE =', mse(b1_test, pred))
print('MAE =', mae(b1_test, pred))
print('R2 Score =', r2_score(b1_test, pred))
# Out:
# MSE = 75.73982603812325
# MAE = 6.9043213361110265
# R2 Score = 0.32819981005405485

# %%
score_p.append([mse(b1_test, pred),mae(b1_test, pred)])

# %% [markdown]
# XGB Regression

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
XGBModel = XGBRegressor()
XGBModel.fit(a1_train,b1_train , verbose=True)

# Get the mean absolute error on the validation data :
XGBpredictions = XGBModel.predict(a1_test)
MAE = mean_absolute_error(b1_test , XGBpredictions)
MSE = mean_squared_error(b1_test, XGBpredictions)
print('XGBoost validation MAE = ',MAE)
print('XGBoost validation MSE = ',MSE)
print('R2 Score =', r2_score(XGBpredictions, b1_test))
# Out:
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [16:07:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBoost validation MAE =  3.6932588228538985
# XGBoost validation MSE =  22.292525356585106
# R2 Score = 0.6894761149914925

# %%
score_p.append([MSE, MAE])

# %% [markdown]
# ##Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
from keras.callbacks import History 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = a1_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4409: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               2816
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 299,265
# Trainable params: 299,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import History 
history = History()
History=NN_model.fit(a1_train, b1_train, epochs=50, batch_size=500, validation_data=(a1_test, b1_test), callbacks=[history])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 127784 samples, validate on 54765 samples
# Epoch 1/50
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 127784/127784 [==============================] - 11s 87us/step - loss: 138.6301 - mean_absolute_error: 8.6604 - val_loss: 72.0540 - val_mean_absolute_error: 6.8178
# Epoch 2/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 66.8706 - mean_absolute_error: 6.5253 - val_loss: 61.5165 - val_mean_absolute_error: 6.2405
# Epoch 3/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 58.4683 - mean_absolute_error: 6.0492 - val_loss: 56.2820 - val_mean_absolute_error: 5.9461
# Epoch 4/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 52.4166 - mean_absolute_error: 5.6514 - val_loss: 50.3132 - val_mean_absolute_error: 5.4689
# Epoch 5/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 47.3632 - mean_absolute_error: 5.2966 - val_loss: 46.8135 - val_mean_absolute_error: 5.2842
# Epoch 6/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 43.0906 - mean_absolute_error: 4.9942 - val_loss: 41.0043 - val_mean_absolute_error: 4.9011
# Epoch 7/50
# 127784/127784 [==============================] - 2s 14us/step - loss: 39.6281 - mean_absolute_error: 4.7400 - val_loss: 39.3913 - val_mean_absolute_error: 4.7520
# Epoch 8/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 37.3668 - mean_absolute_error: 4.5765 - val_loss: 35.8126 - val_mean_absolute_error: 4.4313
# Epoch 9/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 34.9591 - mean_absolute_error: 4.3923 - val_loss: 37.1264 - val_mean_absolute_error: 4.5214
# Epoch 10/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 33.6635 - mean_absolute_error: 4.2868 - val_loss: 31.8343 - val_mean_absolute_error: 4.1694
# Epoch 11/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 31.5468 - mean_absolute_error: 4.1181 - val_loss: 34.2935 - val_mean_absolute_error: 4.4252
# Epoch 12/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 29.1514 - mean_absolute_error: 3.9455 - val_loss: 28.6487 - val_mean_absolute_error: 3.9026
# Epoch 13/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 27.1716 - mean_absolute_error: 3.7680 - val_loss: 26.9054 - val_mean_absolute_error: 3.7940
# Epoch 14/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 25.6136 - mean_absolute_error: 3.6488 - val_loss: 31.7129 - val_mean_absolute_error: 3.8770
# Epoch 15/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 24.3998 - mean_absolute_error: 3.5406 - val_loss: 24.6862 - val_mean_absolute_error: 3.4961
# Epoch 16/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 21.7785 - mean_absolute_error: 3.3280 - val_loss: 21.0625 - val_mean_absolute_error: 3.2403
# Epoch 17/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 20.7059 - mean_absolute_error: 3.2208 - val_loss: 21.1979 - val_mean_absolute_error: 3.2610
# Epoch 18/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 20.5892 - mean_absolute_error: 3.1540 - val_loss: 19.3179 - val_mean_absolute_error: 3.0805
# Epoch 19/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 18.8739 - mean_absolute_error: 3.0326 - val_loss: 19.3092 - val_mean_absolute_error: 3.0325
# Epoch 20/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 18.0493 - mean_absolute_error: 2.9526 - val_loss: 17.6170 - val_mean_absolute_error: 2.8876
# Epoch 21/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 17.3554 - mean_absolute_error: 2.8643 - val_loss: 16.9718 - val_mean_absolute_error: 2.8867
# Epoch 22/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 17.0352 - mean_absolute_error: 2.8250 - val_loss: 16.6658 - val_mean_absolute_error: 2.8548
# Epoch 23/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 14.9893 - mean_absolute_error: 2.6484 - val_loss: 15.7477 - val_mean_absolute_error: 2.7329
# Epoch 24/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 15.1174 - mean_absolute_error: 2.6485 - val_loss: 15.4306 - val_mean_absolute_error: 2.6462
# Epoch 25/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 14.0106 - mean_absolute_error: 2.5439 - val_loss: 13.5303 - val_mean_absolute_error: 2.4813
# Epoch 26/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 13.6082 - mean_absolute_error: 2.4699 - val_loss: 14.7444 - val_mean_absolute_error: 2.6045
# Epoch 27/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 14.1881 - mean_absolute_error: 2.4899 - val_loss: 15.4884 - val_mean_absolute_error: 2.5604
# Epoch 28/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 13.4500 - mean_absolute_error: 2.4091 - val_loss: 13.4901 - val_mean_absolute_error: 2.4186
# Epoch 29/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 13.9621 - mean_absolute_error: 2.4459 - val_loss: 12.1326 - val_mean_absolute_error: 2.2973
# Epoch 30/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 12.0462 - mean_absolute_error: 2.2645 - val_loss: 11.6982 - val_mean_absolute_error: 2.2149
# Epoch 31/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 11.7034 - mean_absolute_error: 2.2147 - val_loss: 11.8330 - val_mean_absolute_error: 2.2012
# Epoch 32/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 11.7307 - mean_absolute_error: 2.2074 - val_loss: 11.8974 - val_mean_absolute_error: 2.2001
# Epoch 33/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 11.4041 - mean_absolute_error: 2.1583 - val_loss: 11.5964 - val_mean_absolute_error: 2.2144
# Epoch 34/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 11.1451 - mean_absolute_error: 2.1167 - val_loss: 12.6129 - val_mean_absolute_error: 2.4183
# Epoch 35/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 11.3453 - mean_absolute_error: 2.1347 - val_loss: 11.2110 - val_mean_absolute_error: 2.0742
# Epoch 36/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 10.9311 - mean_absolute_error: 2.0928 - val_loss: 12.3845 - val_mean_absolute_error: 2.1930
# Epoch 37/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 10.4847 - mean_absolute_error: 2.0272 - val_loss: 10.7101 - val_mean_absolute_error: 2.1122
# Epoch 38/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 10.4002 - mean_absolute_error: 2.0098 - val_loss: 10.3654 - val_mean_absolute_error: 1.9345
# Epoch 39/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 10.0552 - mean_absolute_error: 1.9795 - val_loss: 9.9722 - val_mean_absolute_error: 2.0415
# Epoch 40/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 10.4067 - mean_absolute_error: 1.9921 - val_loss: 12.2239 - val_mean_absolute_error: 2.2191
# Epoch 41/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 10.1812 - mean_absolute_error: 1.9815 - val_loss: 8.8795 - val_mean_absolute_error: 1.8300
# Epoch 42/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 9.8222 - mean_absolute_error: 1.9083 - val_loss: 9.5671 - val_mean_absolute_error: 1.9889
# Epoch 43/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 9.3770 - mean_absolute_error: 1.8860 - val_loss: 10.3232 - val_mean_absolute_error: 1.9936
# Epoch 44/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 8.9752 - mean_absolute_error: 1.8359 - val_loss: 8.6552 - val_mean_absolute_error: 1.8571
# Epoch 45/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 9.8323 - mean_absolute_error: 1.9088 - val_loss: 11.7288 - val_mean_absolute_error: 2.0602
# Epoch 46/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 8.7360 - mean_absolute_error: 1.7972 - val_loss: 9.6380 - val_mean_absolute_error: 1.8914
# Epoch 47/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 8.5662 - mean_absolute_error: 1.7832 - val_loss: 11.1204 - val_mean_absolute_error: 1.9582
# Epoch 48/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 8.8052 - mean_absolute_error: 1.7919 - val_loss: 8.4245 - val_mean_absolute_error: 1.7301
# Epoch 49/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 9.6784 - mean_absolute_error: 1.8467 - val_loss: 9.2443 - val_mean_absolute_error: 1.9016
# Epoch 50/50
# 127784/127784 [==============================] - 2s 13us/step - loss: 8.5558 - mean_absolute_error: 1.7351 - val_loss: 8.7673 - val_mean_absolute_error: 1.7504

# %% [markdown]
# ##Plotting Graphs

# %%
plt.plot(History.history['mean_absolute_error'])
plt.plot(History.history['val_mean_absolute_error'])
plt.title('mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
 # summarize history for loss
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('model loss')
plt.ylabel('mean_squared_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
score_p.append([8.7673, 1.7504])

# %%
score_p
# Out:
# [[64.98646830324311, 6.16041791367379],
#  [75.73982603812325, 6.9043213361110265],
#  [22.292525356585106, 3.6932588228538985],
#  [8.7673, 1.7504]]

# %% [markdown]
# ## Performance Metrics of Various Methods

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

objects = ['MSE', 'MAE']
w =  0.15
y_pos = np.arange(len(objects))

color = ['#A00000','#00A0A0','#00A000', '#FFFF00']
s = 0
for i in range(len(score_p)):
    plt.bar(y_pos+s, score_p[i], color = color[i], width = w )
    s += w
    
plt.xticks(y_pos + 0.22, objects)
plt.ylabel('Scores')
plt.title('Performance')
plt.suptitle("Performance Metrics for Models", fontsize = 16, y = 1.10)

p = ['RANDOM FOREST',  'SVM', 'XGB Regression', 'Neural Network']

patches = []

for k in range(len(p)):
    patches.append(mpatches.Patch(color = color[k], label = p[k]))

plt.legend(handles = patches, bbox_to_anchor = (0.5, 1.19),loc = 'upper center', borderaxespad = 0., ncol = 4, fontsize = 'x-large')

plt.show();

# %% [markdown]
# #**Case study : Crop Counting**

# %% [markdown]
# ##All import Statements

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
from keras.preprocessing import image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import glob
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ##Reading The CSV

# %%
train = pd.read_csv('/content/drive/My Drive/Bennet/number_final.csv')    # reading the csv file
train.head()      # printing first five rows of the file

# %%
train.columns
# Out:
# Index(['ID', 'no'], dtype='object')

# %%
train.shape
# Out:
# (10, 2)

# %% [markdown]
# ##Reading And Loading Images

# %%
filelist = glob.glob('/content/drive/My Drive/Bennet/images/*.jpg')
filelist
# Out:
# ['/content/drive/My Drive/Bennet/images/4.jpg',
#  '/content/drive/My Drive/Bennet/images/7.jpg',
#  '/content/drive/My Drive/Bennet/images/8.jpg',
#  '/content/drive/My Drive/Bennet/images/0.jpg',
#  '/content/drive/My Drive/Bennet/images/1.jpg',
#  '/content/drive/My Drive/Bennet/images/5.jpg',
#  '/content/drive/My Drive/Bennet/images/2.jpg',
#  '/content/drive/My Drive/Bennet/images/3.jpg',
#  '/content/drive/My Drive/Bennet/images/6.jpg',
#  '/content/drive/My Drive/Bennet/images/9.jpg']

# %%
train_image = []

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/0.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/1.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/2.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/3.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/4.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/5.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/6.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/7.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/8.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
img = image.load_img('/content/drive/My Drive/Bennet/images/9.jpg',target_size=(400,400,3))
img = image.img_to_array(img)
img = img/255
train_image.append(img)

# %%
X = np.array(train_image)

# %%
X.shape
# Out:
# (10, 400, 400, 3)

# %% [markdown]
# ##Plotting an image and seeing Result

# %%
plt.imshow(X[2])

# %%
train['no'][2]
# Out:
# 94

# %%
y = np.array(train.drop(['ID'],axis=1))
y.shape
# Out:
# (10, 1)

# %% [markdown]
# Train and Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %% [markdown]
# CNN Regressor

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape = (400,400,3)))
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

model.add(Flatten())
model.add(Dense(64, kernel_initializer='normal', activation='relu'))

model.add(Dropout(0.25))
model.add(Dense(64, kernel_initializer='normal', activation='relu'))

model.add(Dropout(0.25))
model.add(Dense(64, kernel_initializer='normal', activation='relu'))

model.add(Dense(1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 398, 398, 32)      896
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 396, 396, 32)      9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 198, 198, 32)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 196, 196, 32)      9248
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 194, 194, 32)      9248
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 97, 97, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 95, 95, 32)        9248
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 93, 93, 32)        9248
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 46, 46, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 67712)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                4333632
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 4,389,153
# Trainable params: 4,389,153
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Compile and Fit

# %%
model.compile(optimizer = 'adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
from keras.callbacks import History
history = History()
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), verbose=True)
# Out:
# Train on 8 samples, validate on 2 samples
# Epoch 1/100
# 8/8 [==============================] - 1s 116ms/step - loss: 7558.3262 - mean_absolute_error: 78.4631 - val_loss: 1820.6489 - val_mean_absolute_error: 38.2464
# Epoch 2/100
# 8/8 [==============================] - 0s 7ms/step - loss: 7458.0508 - mean_absolute_error: 77.7955 - val_loss: 1648.1426 - val_mean_absolute_error: 36.0254
# Epoch 3/100
# 8/8 [==============================] - 0s 7ms/step - loss: 7117.7471 - mean_absolute_error: 75.4289 - val_loss: 1270.6399 - val_mean_absolute_error: 30.6207
# Epoch 4/100
# 8/8 [==============================] - 0s 7ms/step - loss: 6080.9873 - mean_absolute_error: 68.5037 - val_loss: 644.5364 - val_mean_absolute_error: 18.6463
# Epoch 5/100
# 8/8 [==============================] - 0s 7ms/step - loss: 4512.2988 - mean_absolute_error: 54.5581 - val_loss: 288.1163 - val_mean_absolute_error: 15.0284
# Epoch 6/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2475.6812 - mean_absolute_error: 40.5470 - val_loss: 4217.0605 - val_mean_absolute_error: 64.0889
# Epoch 7/100
# 8/8 [==============================] - 0s 6ms/step - loss: 4947.1528 - mean_absolute_error: 64.7829 - val_loss: 2028.8590 - val_mean_absolute_error: 43.3636
# Epoch 8/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2296.8535 - mean_absolute_error: 40.7636 - val_loss: 664.0423 - val_mean_absolute_error: 21.6543
# Epoch 9/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2768.7695 - mean_absolute_error: 43.3214 - val_loss: 289.2036 - val_mean_absolute_error: 15.1129
# Epoch 10/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2569.6365 - mean_absolute_error: 39.4665 - val_loss: 247.1248 - val_mean_absolute_error: 15.7099
# Epoch 11/100
# 8/8 [==============================] - 0s 6ms/step - loss: 2925.3210 - mean_absolute_error: 39.7232 - val_loss: 253.5720 - val_mean_absolute_error: 15.8664
# Epoch 12/100
# 8/8 [==============================] - 0s 7ms/step - loss: 3213.3540 - mean_absolute_error: 42.5613 - val_loss: 249.0270 - val_mean_absolute_error: 15.7774
# Epoch 13/100
# 8/8 [==============================] - 0s 6ms/step - loss: 3086.7605 - mean_absolute_error: 44.1020 - val_loss: 259.8482 - val_mean_absolute_error: 15.3394
# Epoch 14/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2642.3262 - mean_absolute_error: 37.3934 - val_loss: 415.9249 - val_mean_absolute_error: 14.5800
# Epoch 15/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2122.5044 - mean_absolute_error: 31.2230 - val_loss: 924.2027 - val_mean_absolute_error: 27.2315
# Epoch 16/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1773.8630 - mean_absolute_error: 34.4573 - val_loss: 1731.5742 - val_mean_absolute_error: 39.6838
# Epoch 17/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2212.7373 - mean_absolute_error: 40.5511 - val_loss: 1734.3434 - val_mean_absolute_error: 39.7109
# Epoch 18/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2229.6555 - mean_absolute_error: 38.9012 - val_loss: 1372.2975 - val_mean_absolute_error: 34.6992
# Epoch 19/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1661.6738 - mean_absolute_error: 36.3840 - val_loss: 1105.3455 - val_mean_absolute_error: 30.4542
# Epoch 20/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1899.4232 - mean_absolute_error: 33.5782 - val_loss: 804.1510 - val_mean_absolute_error: 24.7658
# Epoch 21/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1557.8900 - mean_absolute_error: 25.2915 - val_loss: 650.3433 - val_mean_absolute_error: 21.2422
# Epoch 22/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1362.2491 - mean_absolute_error: 28.7580 - val_loss: 592.2955 - val_mean_absolute_error: 19.7293
# Epoch 23/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2435.5811 - mean_absolute_error: 38.4043 - val_loss: 568.7599 - val_mean_absolute_error: 19.0681
# Epoch 24/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2277.4873 - mean_absolute_error: 37.4611 - val_loss: 678.1611 - val_mean_absolute_error: 21.8793
# Epoch 25/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1773.4014 - mean_absolute_error: 32.5693 - val_loss: 817.9072 - val_mean_absolute_error: 24.9951
# Epoch 26/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1923.3296 - mean_absolute_error: 33.4878 - val_loss: 978.7545 - val_mean_absolute_error: 28.1411
# Epoch 27/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2122.4763 - mean_absolute_error: 40.8576 - val_loss: 848.4506 - val_mean_absolute_error: 25.5924
# Epoch 28/100
# 8/8 [==============================] - 0s 7ms/step - loss: 939.0868 - mean_absolute_error: 25.1312 - val_loss: 781.6567 - val_mean_absolute_error: 24.1723
# Epoch 29/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2497.0017 - mean_absolute_error: 38.8126 - val_loss: 585.6613 - val_mean_absolute_error: 19.4202
# Epoch 30/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2722.4214 - mean_absolute_error: 44.8157 - val_loss: 465.6845 - val_mean_absolute_error: 15.7602
# Epoch 31/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2483.4531 - mean_absolute_error: 34.6030 - val_loss: 445.6843 - val_mean_absolute_error: 15.0541
# Epoch 32/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2450.3960 - mean_absolute_error: 37.2633 - val_loss: 509.3815 - val_mean_absolute_error: 17.1832
# Epoch 33/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1888.6870 - mean_absolute_error: 36.7780 - val_loss: 595.4650 - val_mean_absolute_error: 19.6705
# Epoch 34/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2128.6292 - mean_absolute_error: 32.5374 - val_loss: 735.5231 - val_mean_absolute_error: 23.1206
# Epoch 35/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2504.8818 - mean_absolute_error: 40.4628 - val_loss: 1008.2299 - val_mean_absolute_error: 28.6126
# Epoch 36/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1301.8384 - mean_absolute_error: 29.9975 - val_loss: 1338.1824 - val_mean_absolute_error: 34.0592
# Epoch 37/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1968.5874 - mean_absolute_error: 37.5101 - val_loss: 1052.5649 - val_mean_absolute_error: 29.3988
# Epoch 38/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1404.1453 - mean_absolute_error: 30.7652 - val_loss: 755.3763 - val_mean_absolute_error: 23.5406
# Epoch 39/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2096.1021 - mean_absolute_error: 36.2416 - val_loss: 519.0989 - val_mean_absolute_error: 17.4414
# Epoch 40/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1383.8010 - mean_absolute_error: 30.6674 - val_loss: 438.3969 - val_mean_absolute_error: 14.8727
# Epoch 41/100
# 8/8 [==============================] - 0s 6ms/step - loss: 2429.9810 - mean_absolute_error: 38.7151 - val_loss: 445.4718 - val_mean_absolute_error: 14.9894
# Epoch 42/100
# 8/8 [==============================] - 0s 7ms/step - loss: 3020.8831 - mean_absolute_error: 44.1562 - val_loss: 500.1625 - val_mean_absolute_error: 16.8381
# Epoch 43/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1556.8945 - mean_absolute_error: 24.8283 - val_loss: 705.8759 - val_mean_absolute_error: 22.3924
# Epoch 44/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1822.9414 - mean_absolute_error: 32.1696 - val_loss: 1104.8975 - val_mean_absolute_error: 30.2844
# Epoch 45/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2538.1245 - mean_absolute_error: 42.2722 - val_loss: 1040.7950 - val_mean_absolute_error: 29.1568
# Epoch 46/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1546.4802 - mean_absolute_error: 32.2295 - val_loss: 750.9478 - val_mean_absolute_error: 23.4015
# Epoch 47/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1440.5660 - mean_absolute_error: 29.1771 - val_loss: 463.5254 - val_mean_absolute_error: 15.5614
# Epoch 48/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1474.8080 - mean_absolute_error: 30.8026 - val_loss: 345.6757 - val_mean_absolute_error: 15.2663
# Epoch 49/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1948.8030 - mean_absolute_error: 31.4072 - val_loss: 345.9600 - val_mean_absolute_error: 15.2880
# Epoch 50/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1690.7283 - mean_absolute_error: 30.7662 - val_loss: 436.7366 - val_mean_absolute_error: 15.0116
# Epoch 51/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1401.3870 - mean_absolute_error: 30.4229 - val_loss: 695.2819 - val_mean_absolute_error: 22.0533
# Epoch 52/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1279.9500 - mean_absolute_error: 26.1068 - val_loss: 1196.6958 - val_mean_absolute_error: 31.7646
# Epoch 53/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1786.9644 - mean_absolute_error: 33.0814 - val_loss: 1616.8302 - val_mean_absolute_error: 37.9721
# Epoch 54/100
# 8/8 [==============================] - 0s 6ms/step - loss: 2204.2917 - mean_absolute_error: 38.3575 - val_loss: 1764.2258 - val_mean_absolute_error: 39.9057
# Epoch 55/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2371.1133 - mean_absolute_error: 42.0674 - val_loss: 1061.2805 - val_mean_absolute_error: 29.4585
# Epoch 56/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1594.7844 - mean_absolute_error: 31.2083 - val_loss: 713.2996 - val_mean_absolute_error: 22.4647
# Epoch 57/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1842.9457 - mean_absolute_error: 35.8512 - val_loss: 452.0561 - val_mean_absolute_error: 15.0663
# Epoch 58/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1436.0403 - mean_absolute_error: 30.8871 - val_loss: 381.3661 - val_mean_absolute_error: 15.2140
# Epoch 59/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1830.2395 - mean_absolute_error: 34.8648 - val_loss: 411.3403 - val_mean_absolute_error: 15.1212
# Epoch 60/100
# 8/8 [==============================] - 0s 8ms/step - loss: 2523.1646 - mean_absolute_error: 40.2906 - val_loss: 516.5787 - val_mean_absolute_error: 17.1653
# Epoch 61/100
# 8/8 [==============================] - 0s 7ms/step - loss: 991.3627 - mean_absolute_error: 23.7358 - val_loss: 859.5560 - val_mean_absolute_error: 25.6059
# Epoch 62/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2280.2188 - mean_absolute_error: 42.1032 - val_loss: 1159.6700 - val_mean_absolute_error: 31.0963
# Epoch 63/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1608.7634 - mean_absolute_error: 29.8211 - val_loss: 1528.4830 - val_mean_absolute_error: 36.7088
# Epoch 64/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2203.1025 - mean_absolute_error: 38.5416 - val_loss: 1323.9429 - val_mean_absolute_error: 33.7127
# Epoch 65/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2642.0571 - mean_absolute_error: 44.8540 - val_loss: 683.1323 - val_mean_absolute_error: 21.6971
# Epoch 66/100
# 8/8 [==============================] - 0s 6ms/step - loss: 907.9852 - mean_absolute_error: 24.9445 - val_loss: 504.2361 - val_mean_absolute_error: 16.7690
# Epoch 67/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1419.5007 - mean_absolute_error: 33.0028 - val_loss: 457.5783 - val_mean_absolute_error: 15.1959
# Epoch 68/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1196.0890 - mean_absolute_error: 25.1940 - val_loss: 482.2968 - val_mean_absolute_error: 16.0467
# Epoch 69/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1608.5773 - mean_absolute_error: 29.5160 - val_loss: 603.8196 - val_mean_absolute_error: 19.6483
# Epoch 70/100
# 8/8 [==============================] - 0s 7ms/step - loss: 2004.6499 - mean_absolute_error: 36.2231 - val_loss: 565.7047 - val_mean_absolute_error: 18.5870
# Epoch 71/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1916.2488 - mean_absolute_error: 33.3285 - val_loss: 568.8763 - val_mean_absolute_error: 18.6735
# Epoch 72/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1235.0505 - mean_absolute_error: 25.4898 - val_loss: 566.9092 - val_mean_absolute_error: 18.6220
# Epoch 73/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1493.6799 - mean_absolute_error: 26.7281 - val_loss: 699.0406 - val_mean_absolute_error: 22.0747
# Epoch 74/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1056.8694 - mean_absolute_error: 22.3390 - val_loss: 1121.4629 - val_mean_absolute_error: 30.4863
# Epoch 75/100
# 8/8 [==============================] - 0s 6ms/step - loss: 1414.4720 - mean_absolute_error: 30.1164 - val_loss: 1026.4480 - val_mean_absolute_error: 28.8213
# Epoch 76/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1231.4069 - mean_absolute_error: 27.8015 - val_loss: 707.4394 - val_mean_absolute_error: 22.2983
# Epoch 77/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1047.5905 - mean_absolute_error: 26.3749 - val_loss: 388.5284 - val_mean_absolute_error: 15.2122
# Epoch 78/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1329.7180 - mean_absolute_error: 28.6255 - val_loss: 299.7049 - val_mean_absolute_error: 15.5688
# Epoch 79/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1343.0283 - mean_absolute_error: 31.6338 - val_loss: 313.0798 - val_mean_absolute_error: 15.5113
# Epoch 80/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1275.6904 - mean_absolute_error: 28.6055 - val_loss: 436.4329 - val_mean_absolute_error: 15.0729
# Epoch 81/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1079.4641 - mean_absolute_error: 24.2102 - val_loss: 956.7369 - val_mean_absolute_error: 27.5608
# Epoch 82/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1281.4817 - mean_absolute_error: 32.3226 - val_loss: 1148.1606 - val_mean_absolute_error: 30.9568
# Epoch 83/100
# 8/8 [==============================] - 0s 7ms/step - loss: 726.4113 - mean_absolute_error: 21.6199 - val_loss: 753.6815 - val_mean_absolute_error: 23.3898
# Epoch 84/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1669.2263 - mean_absolute_error: 34.5177 - val_loss: 484.5052 - val_mean_absolute_error: 16.1936
# Epoch 85/100
# 8/8 [==============================] - 0s 7ms/step - loss: 541.4993 - mean_absolute_error: 17.0928 - val_loss: 330.4355 - val_mean_absolute_error: 15.3583
# Epoch 86/100
# 8/8 [==============================] - 0s 7ms/step - loss: 661.8083 - mean_absolute_error: 20.0996 - val_loss: 368.3554 - val_mean_absolute_error: 15.2362
# Epoch 87/100
# 8/8 [==============================] - 0s 7ms/step - loss: 882.1543 - mean_absolute_error: 21.5878 - val_loss: 587.5112 - val_mean_absolute_error: 19.2678
# Epoch 88/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1014.7882 - mean_absolute_error: 27.6641 - val_loss: 1021.0218 - val_mean_absolute_error: 28.7202
# Epoch 89/100
# 8/8 [==============================] - 0s 7ms/step - loss: 898.7036 - mean_absolute_error: 22.2950 - val_loss: 706.5769 - val_mean_absolute_error: 22.2696
# Epoch 90/100
# 8/8 [==============================] - 0s 7ms/step - loss: 943.7753 - mean_absolute_error: 26.6441 - val_loss: 426.5495 - val_mean_absolute_error: 15.1038
# Epoch 91/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1119.9247 - mean_absolute_error: 23.9530 - val_loss: 361.0849 - val_mean_absolute_error: 15.2916
# Epoch 92/100
# 8/8 [==============================] - 0s 7ms/step - loss: 799.2294 - mean_absolute_error: 22.9345 - val_loss: 560.6088 - val_mean_absolute_error: 18.4618
# Epoch 93/100
# 8/8 [==============================] - 0s 7ms/step - loss: 534.5601 - mean_absolute_error: 19.8999 - val_loss: 829.2449 - val_mean_absolute_error: 24.9595
# Epoch 94/100
# 8/8 [==============================] - 0s 7ms/step - loss: 176.4147 - mean_absolute_error: 11.4870 - val_loss: 901.3666 - val_mean_absolute_error: 26.4356
# Epoch 95/100
# 8/8 [==============================] - 0s 7ms/step - loss: 545.2089 - mean_absolute_error: 20.8949 - val_loss: 385.1295 - val_mean_absolute_error: 15.1890
# Epoch 96/100
# 8/8 [==============================] - 0s 7ms/step - loss: 746.8269 - mean_absolute_error: 25.7119 - val_loss: 259.7026 - val_mean_absolute_error: 15.7356
# Epoch 97/100
# 8/8 [==============================] - 0s 7ms/step - loss: 1455.7675 - mean_absolute_error: 30.3833 - val_loss: 272.3276 - val_mean_absolute_error: 15.7108
# Epoch 98/100
# 8/8 [==============================] - 0s 7ms/step - loss: 844.6243 - mean_absolute_error: 22.8834 - val_loss: 464.3337 - val_mean_absolute_error: 15.3167
# Epoch 99/100
# 8/8 [==============================] - 0s 7ms/step - loss: 190.1071 - mean_absolute_error: 12.1427 - val_loss: 1157.2520 - val_mean_absolute_error: 30.9419
# Epoch 100/100
# 8/8 [==============================] - 0s 7ms/step - loss: 770.7931 - mean_absolute_error: 21.0835 - val_loss: 873.4758 - val_mean_absolute_error: 25.6565

# %% [markdown]
# ##Plotting the Graphs

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model mean_absolute_error')
plt.ylabel('mean_absolute_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
 # summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model mean squared error')
plt.ylabel('mean_squared_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ##Predictions

# %%
model.predict(X_test)
# Out:
# array([[60.32685 ],
#        [68.986206]], dtype=float32)

# %%
model.predict(X_train)
# Out:
# array([[ 91.25734 ],
#        [ 59.422874],
#        [ 74.94933 ],
#        [ 93.70494 ],
#        [ 84.651215],
#        [ 62.424236],
#        [155.82098 ],
#        [ 72.66931 ]], dtype=float32)
